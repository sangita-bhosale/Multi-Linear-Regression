# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.graphics.regressionplots import influence_plot

# %%
data=pd.read_csv('50_Startups.csv')

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ## EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.8+ KB

# %%
data1=data.rename({'R&D Spend':'RAD','Administration':'ADM','Marketing Spend':'MRS'}, axis=1)

# %%
data1
# Out:
#           RAD        ADM        MRS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
data1[data1.duplicated()]
# no duplicate data found.
# Out:
# Empty DataFrame
# Columns: [RAD, ADM, MRS, State, Profit]
# Index: []

# %%
data1.describe()
# Out:
#                  RAD            ADM            MRS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %% [markdown]
# ## correlation Analysis

# %%
data1.corr()
# Out:
#              RAD       ADM       MRS    Profit
# RAD     1.000000  0.241955  0.724248  0.972900
# ADM     0.241955  1.000000 -0.032154  0.200717
# MRS     0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.set_style(style='whitegrid')

# %%
sns.pairplot(data1)

# %% [markdown]
# ## Model building

# %%
model=smf.ols("Profit~RAD+ADM+MRS",data=data1).fit()

# %%
model

# %% [markdown]
# ## Model Testing

# %%
# To find Coefficient parameters
model.params
# Out:
# Intercept    50122.192990
# RAD              0.805715
# ADM             -0.026816
# MRS              0.027228
# dtype: float64

# %%
# to find tvalues and pvalues
model.tvalues ,np.round(model.pvalues,5)
# Out:
# (Intercept     7.626218
#  RAD          17.846374
#  ADM          -0.525507
#  MRS           1.655077
#  dtype: float64,
#  Intercept    0.00000
#  RAD          0.00000
#  ADM          0.60176
#  MRS          0.10472
#  dtype: float64)

# %%
# To find rsquared values
model.rsquared , model.rsquared_adj  ## Model accuracy is 94.75%
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
###  to Build SLR and MLR models for insignificant variables 'ADM' and 'MRS'
### Also find their tvalues and pvalues

# %%
slr_a=smf.ols("Profit~ADM",data=data1).fit()
slr_a.tvalues , slr_a.pvalues
# Out:
# (Intercept    3.040044
#  ADM          1.419493
#  dtype: float64,
#  Intercept    0.003824
#  ADM          0.162217
#  dtype: float64)

# %%
slr_m=smf.ols("Profit~MRS",data=data1).fit()
slr_m.tvalues , slr_m.pvalues  # MRS has significant pvalue
# Out:
# (Intercept    7.808356
#  MRS          7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  MRS          4.381073e-10
#  dtype: float64)

# %%
mlr_am=smf.ols("Profit~ADM+MRS",data=data1).fit()
mlr_am.tvalues , mlr_am.pvalues  # varaibles have significant pvalues
# Out:
# (Intercept    1.142741
#  ADM          2.467779
#  MRS          8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  ADM          1.729198e-02
#  MRS          9.727245e-11
#  dtype: float64)

# %% [markdown]
# ## Model Validation
# ## Two Techniques: 1. Collinearity Check & 2. Residual Analysis

# %%
# 1) Collinearity Problem Check
# Calculate VIF = 1/(1-Rsquare) for all independent variables

# %%
rsq_r=smf.ols("RAD~ADM+MRS",data=data1).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("ADM~RAD+MRS",data=data1).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("MRS~RAD+ADM",data=data1).fit().rsquared
vif_m=1/(1-rsq_m)

# Putting the values in Dataframe format
d1={'Variables':['RAD','ADM','MRS'],'Vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       RAD  2.468903
# 1       ADM  1.175091
# 2       MRS  2.326773

# %%
# None variable has VIF>20, No Collinearity, so consider all varaibles in Regression equation

# %%
# 2) Residual Analysis
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)

sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49], dtype=int32)]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vsstandardized residual values)

def standard_values(vals) : return (vals-vals.mean())/vals.std()  # User defined z = (x - mu)/sigma

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'RAD',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'ADM',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'MRS',fig=fig)
plt.show()

# %% [markdown]
# ## Model Deletion Diagnostics (checking Outliers or Influencers)

# %% [markdown]
# ## Two techniques :
# 1. Cook's Distance.
# 2. Leverage value.

# %%
## 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data1)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (49, 0.28808229275432673)

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(model)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=data1.shape[1]
n=data1.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
data1[data1.index.isin([49])]
# Out:
#     RAD       ADM       MRS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %% [markdown]
# ## Improving the Model

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
data_2=data1.drop(data1.index[[49]],axis=0).reset_index(drop=True)
data_2
# Out:
#           RAD        ADM        MRS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# ## Model Deletion Diagnostics and Final Model

# %%
model_b=smf.ols("Profit~RAD+ADM+MRS",data=data_2).fit()
model_b

# %%
while model_b.rsquared < 0.99:
    for c in [np.max(c)>1]:
        model_b=smf.ols("Profit~RAD+ADM+MRS",data=data_2).fit()
        (c,_)=model2.get_influence().cooks_distance
        c
        np.argmax(c) , np.max(c)
        data_2=data_2.drop(data_2.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
        data_2
    else:
        final_model=smf.ols("Profit~RAD+ADM+MRS",data=data_2).fit()
        final_model.rsquared , final_model.aic
        print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.985966539884925
# Thus model accuracy is improved to 0.9836151210221631
# Thus model accuracy is improved to 0.9800394628173511
# Thus model accuracy is improved to 0.9752401009027254
# Thus model accuracy is improved to 0.9659864897953456
# Thus model accuracy is improved to 0.9714620507800351
# Thus model accuracy is improved to 0.9688587505584183
# Thus model accuracy is improved to 0.9651893680035891
# Thus model accuracy is improved to 0.9584900239441909
# Thus model accuracy is improved to 0.9602935510095415
# Thus model accuracy is improved to 0.9579384136052252
# Thus model accuracy is improved to 0.9632696488370222
# Thus model accuracy is improved to 0.9693326271111199
# Thus model accuracy is improved to 0.9661062638611158
# Thus model accuracy is improved to 0.9645261615751761
# Thus model accuracy is improved to 0.9626765582521997
# Thus model accuracy is improved to 0.9590679742113937
# ...

# %%
final_model.rsquared
# Out:
# 1.0

# %%
data_2
# Out:
#         RAD        ADM        MRS       State    Profit
# 0  27892.92   84710.77  164470.71     Florida  77798.83
# 1  23640.93   96189.63  148001.11  California  71498.49
# 2  22177.74  154806.14   28334.72  California  65200.33

# %% [markdown]
# ## model prediction**********

# %%
# new data for prediction

# %%
new_data=pd.DataFrame({'RAD':70000,"ADM":90000,"MRS":140000},index=[0])
new_data
# Out:
#      RAD    ADM     MRS
# 0  70000  90000  140000

# %%
final_model.predict(new_data) # manual prediction of price with new data
# Out:
# 0    138734.918984
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy
pred_y=final_model.predict(data1)
pred_y
# Out:
# 0     331342.316403
# 1     326418.554800
# 2     298997.293282
# 3     285572.700855
# 4     275043.386034
# 5     260872.964081
# 6     244421.591419
# 7     262070.399847
# 8     246532.550404
# 9     242517.582995
# 10    201377.043871
# 11    198621.760586
# 12    194983.884016
# 13    194039.566650
# 14    240217.933638
# 15    226519.391014
# 16    172017.682103
# 17    203513.311844
# 18    195011.999992
# 19    157566.853022
# 20    172234.326009
# 21    182906.955139
# 22    171073.506160
# 23    158450.078463
# 24    151054.984586
# 25    139616.235389
# 26    155930.310386
# 27    175391.725331
# 28    147154.826087
# 29    139667.595480
# 30    125391.173222
# 31    130564.299963
# 32    124399.333483
# 33    128720.884983
# 34    124728.170699
# 35    110086.221964
# 36     91307.207508
# 37     99907.403417
# 38     65467.123686
# 39     94751.135547
# 40     86350.305252
# 41     77798.830000
# 42     71498.490000
# 43     51066.077644
# 44     65200.330000
# ...

# %% [markdown]
# ## Table containing R^2 value for each prepared model

# %%
data3={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(data3)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  1.000000
